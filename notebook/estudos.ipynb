# %%
import requests

# %%
r = requests.get('https://api.github.com/events')
# base = https://api.github.com
# endpoint= /events

# %%
r.status_code
r.url
r.text
r.json()
# Out:
# [{'id': '37510461794',
#   'type': 'DeleteEvent',
#   'actor': {'id': 10810283,
#    'login': 'direwolf-github',
#    'display_login': 'direwolf-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/direwolf-github',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10810283?'},
#   'repo': {'id': 787510177,
#    'name': 'direwolf-github/ephemeral-ci-72cb770f',
#    'url': 'https://api.github.com/repos/direwolf-github/ephemeral-ci-72cb770f'},
#   'payload': {'ref': 'branch-99eef6ea',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461851',
#   'type': 'WatchEvent',
#   'actor': {'id': 6386745,
#    'login': 'fjibj',
#    'display_login': 'fjibj',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fjibj',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6386745?'},
#   'repo': {'id': 784673135,
#    'name': 'aniket-work/how_made_ai_agent_engage_heated_debate',
#    'url': 'https://api.github.com/repos/aniket-work/how_made_ai_agent_engage_heated_debate'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461772',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 490700222,
#    'name': 'RNy7846/RNY7846',
#    'url': 'https://api.github.com/repos/RNy7846/RNY7846'},
#   'payload': {'repository_id': 490700222,
#    'push_id': 18022982410,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': 'a98ca8beb2be3023092209c14f02d03ed9d2d75c',
#    'before': '16de024df321094dd504ab7aa5fce2ff53b7c131',
#    'commits': [{'sha': 'a98ca8beb2be3023092209c14f02d03ed9d2d75c',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RNy7846/RNY7846/commits/a98ca8beb2be3023092209c14f02d03ed9d2d75c'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461704',
#   'type': 'PushEvent',
#   'actor': {'id': 90259918,
#    'login': 'readywer',
#    'display_login': 'readywer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/readywer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/90259918?'},
#   'repo': {'id': 787508244,
#    'name': 'readywer/Infrend',
#    'url': 'https://api.github.com/repos/readywer/Infrend'},
#   'payload': {'repository_id': 787508244,
#    'push_id': 18022982393,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4f5a870107807f97bbb0bdd645c6a9ea3094c6dc',
#    'before': 'ed6912b26678f7aef3c5597d01a46e641f030c30',
#    'commits': [{'sha': '4f5a870107807f97bbb0bdd645c6a9ea3094c6dc',
#      'author': {'email': '90259918+readywer@users.noreply.github.com',
#       'name': 'readywer'},
#      'message': 'init',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/readywer/Infrend/commits/4f5a870107807f97bbb0bdd645c6a9ea3094c6dc'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461751',
#   'type': 'CreateEvent',
#   'actor': {'id': 100894672,
#    'login': 'Christell040',
#    'display_login': 'Christell040',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Christell040',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/100894672?'},
#   'repo': {'id': 781531679,
#    'name': 'Christell040/React-Phase',
#    'url': 'https://api.github.com/repos/Christell040/React-Phase'},
#   'payload': {'ref': 'redux-todo',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461764',
#   'type': 'PushEvent',
#   'actor': {'id': 81714564,
#    'login': 'Oumaima10',
#    'display_login': 'Oumaima10',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Oumaima10',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81714564?'},
#   'repo': {'id': 784760130,
#    'name': 'Marmim/projet_location',
#    'url': 'https://api.github.com/repos/Marmim/projet_location'},
#   'payload': {'repository_id': 784760130,
#    'push_id': 18022982404,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a9ebc21d219c3e63c6eedf86719098707668c883',
#    'before': 'daa3ad02edc1677e4fb813d20675d7041f402c4c',
#    'commits': [{'sha': 'a9ebc21d219c3e63c6eedf86719098707668c883',
#      'author': {'email': 'oumaimaezzahraa1@gmail.com',
#       'name': 'JAMI Oumaima Ezzahraa'},
#      'message': 'authentification',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Marmim/projet_location/commits/a9ebc21d219c3e63c6eedf86719098707668c883'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461776',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 503760744,
#    'name': 'hako-lnvs/hako',
#    'url': 'https://api.github.com/repos/hako-lnvs/hako'},
#   'payload': {'repository_id': 503760744,
#    'push_id': 18022982405,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': 'e14d7f445fb4e789e6f60ff7dec8690aabd29aed',
#    'before': '4801f46b8c8084376272c640cbe8fafd37bdf581',
#    'commits': [{'sha': '7181d20a14bd0f1c25c6d0757f435f3bef9737c7',
#      'author': {'email': 'hako@lnvs.net', 'name': 'hako-lnvs'},
#      'message': '⬆️ update new posts with github action',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hako-lnvs/hako/commits/7181d20a14bd0f1c25c6d0757f435f3bef9737c7'},
#     {'sha': 'e14d7f445fb4e789e6f60ff7dec8690aabd29aed',
#      'author': {'email': 'hako@lnvs.net', 'name': 'hako-lnvs'},
#      'message': '⬆️ update new posts with github action',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hako-lnvs/hako/commits/e14d7f445fb4e789e6f60ff7dec8690aabd29aed'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461791',
#   'type': 'CreateEvent',
#   'actor': {'id': 116163081,
#    'login': 'aaridhon19',
#    'display_login': 'aaridhon19',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aaridhon19',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/116163081?'},
#   'repo': {'id': 787510456,
#    'name': 'aaridhon19/Speech_N_Images_To_Text',
#    'url': 'https://api.github.com/repos/aaridhon19/Speech_N_Images_To_Text'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461785',
#   'type': 'CreateEvent',
#   'actor': {'id': 130529816,
#    'login': 'eshita241',
#    'display_login': 'eshita241',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eshita241',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/130529816?'},
#   'repo': {'id': 787509754,
#    'name': 'eshita241/Todo-task',
#    'url': 'https://api.github.com/repos/eshita241/Todo-task'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461760',
#   'type': 'PushEvent',
#   'actor': {'id': 74699880,
#    'login': 'matt0923',
#    'display_login': 'matt0923',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/matt0923',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74699880?'},
#   'repo': {'id': 787487874,
#    'name': 'matt0923/Lab2_Starter',
#    'url': 'https://api.github.com/repos/matt0923/Lab2_Starter'},
#   'payload': {'repository_id': 787487874,
#    'push_id': 18022982408,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e6418079a9b988e0504093e5f4bde8ad7fcd7b60',
#    'before': '005b4d1183204b76ee69f88c172b438c4a923e0e',
#    'commits': [{'sha': 'e6418079a9b988e0504093e5f4bde8ad7fcd7b60',
#      'author': {'email': '74699880+matt0923@users.noreply.github.com',
#       'name': 'matt0923'},
#      'message': 'Update index.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/matt0923/Lab2_Starter/commits/e6418079a9b988e0504093e5f4bde8ad7fcd7b60'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461687',
#   'type': 'CreateEvent',
#   'actor': {'id': 12211379,
#    'login': 'rggmiranda',
#    'display_login': 'rggmiranda',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rggmiranda',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12211379?'},
#   'repo': {'id': 787510454,
#    'name': 'rggmiranda/ecommerceAngular',
#    'url': 'https://api.github.com/repos/rggmiranda/ecommerceAngular'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461735',
#   'type': 'CreateEvent',
#   'actor': {'id': 867868,
#    'login': 'natewalck',
#    'display_login': 'natewalck',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natewalck',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/867868?'},
#   'repo': {'id': 618469474,
#    'name': 'macadmins/munki-builds',
#    'url': 'https://api.github.com/repos/macadmins/munki-builds'},
#   'payload': {'ref': 'munkibeta-6.5.0b3',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z',
#   'org': {'id': 8491458,
#    'login': 'macadmins',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/macadmins',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8491458?'}},
#  {'id': '37510461777',
#   'type': 'CreateEvent',
#   'actor': {'id': 11465610,
#    'login': 'jkleinlercher',
#    'display_login': 'jkleinlercher',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jkleinlercher',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11465610?'},
#   'repo': {'id': 787510457,
#    'name': 'suxess-it/m',
#    'url': 'https://api.github.com/repos/suxess-it/m'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'This is m',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z',
#   'org': {'id': 133130537,
#    'login': 'suxess-it',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/suxess-it',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/133130537?'}},
#  {'id': '37510461689',
#   'type': 'PushEvent',
#   'actor': {'id': 6368621,
#    'login': 'sidanmor',
#    'display_login': 'sidanmor',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sidanmor',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6368621?'},
#   'repo': {'id': 177208374,
#    'name': 'sidanmor/contribution-activity',
#    'url': 'https://api.github.com/repos/sidanmor/contribution-activity'},
#   'payload': {'repository_id': 177208374,
#    'push_id': 18022982369,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e845001d3a9d4980f748d264a384113c13755e8f',
#    'before': 'b67ce3b1261501185ae8049e343c1fc4f963971c',
#    'commits': [{'sha': 'e845001d3a9d4980f748d264a384113c13755e8f',
#      'author': {'email': 'sidanmor@gmail.com', 'name': 'Idan Mor'},
#      'message': 'Add one',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sidanmor/contribution-activity/commits/e845001d3a9d4980f748d264a384113c13755e8f'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461717',
#   'type': 'PushEvent',
#   'actor': {'id': 105485108,
#    'login': 'd4eh0',
#    'display_login': 'd4eh0',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/d4eh0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105485108?'},
#   'repo': {'id': 784222461,
#    'name': 'd4eh0/cpp',
#    'url': 'https://api.github.com/repos/d4eh0/cpp'},
#   'payload': {'repository_id': 784222461,
#    'push_id': 18022982385,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd0ca36a09fda06384e6046e481ec9d7f0bf48f3a',
#    'before': '2eddec1340b867427bb3beccf860010810f508f9',
#    'commits': [{'sha': 'd0ca36a09fda06384e6046e481ec9d7f0bf48f3a',
#      'author': {'email': '105485108+d4eh0@users.noreply.github.com',
#       'name': 'd4eh0'},
#      'message': 'practice6-3, ex4-1~4',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/d4eh0/cpp/commits/d0ca36a09fda06384e6046e481ec9d7f0bf48f3a'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461614',
#   'type': 'PushEvent',
#   'actor': {'id': 81297217,
#    'login': 'Daniel-Nlemedim',
#    'display_login': 'Daniel-Nlemedim',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Daniel-Nlemedim',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81297217?'},
#   'repo': {'id': 767508814,
#    'name': 'Daniel-Nlemedim/Bankist-site',
#    'url': 'https://api.github.com/repos/Daniel-Nlemedim/Bankist-site'},
#   'payload': {'repository_id': 767508814,
#    'push_id': 18022982348,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0a4a9d9bfbb8f8ca58e83e279eff1c14f0280504',
#    'before': '678075bad2d914f63d089e0b8a397af72f9e53ad',
#    'commits': [{'sha': '0a4a9d9bfbb8f8ca58e83e279eff1c14f0280504',
#      'author': {'email': 'nzubenlems2002@gmail.com',
#       'name': 'Daniel-Nlemedim'},
#      'message': 'implemented lot of functionalities and designs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Daniel-Nlemedim/Bankist-site/commits/0a4a9d9bfbb8f8ca58e83e279eff1c14f0280504'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461708',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 366949467,
#    'name': 'xoxovo/AutoGreen',
#    'url': 'https://api.github.com/repos/xoxovo/AutoGreen'},
#   'payload': {'repository_id': 366949467,
#    'push_id': 18022982394,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a0ed3fab3cc85c4735898c5b26119ef071db6be6',
#    'before': '598f19a96774c51c82268d33ac11b21b448d142e',
#    'commits': [{'sha': 'a0ed3fab3cc85c4735898c5b26119ef071db6be6',
#      'author': {'email': 'edward.xyz@qq.com', 'name': 'Edward'},
#      'message': 'a commit a day keeps your girlfriend away',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xoxovo/AutoGreen/commits/a0ed3fab3cc85c4735898c5b26119ef071db6be6'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461640',
#   'type': 'PushEvent',
#   'actor': {'id': 61399097,
#    'login': 'Louis-C7',
#    'display_login': 'Louis-C7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Louis-C7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61399097?'},
#   'repo': {'id': 722978074,
#    'name': 'react-native-oh-library/react-native-safe-area-context',
#    'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context'},
#   'payload': {'repository_id': 722978074,
#    'push_id': 18022982352,
#    'size': 11,
#    'distinct_size': 1,
#    'ref': 'refs/heads/sig',
#    'head': 'cd2e3e549d0b0c71db2724d59752ca953c9206c5',
#    'before': 'b99ac643de8ac74b45df331dc335e81d281df6e8',
#    'commits': [{'sha': '84c8f011751e33a5a4432b72b00fd3c5f31125a8',
#      'author': {'email': '1020819393@qq.com', 'name': '陈宝迪'},
#      'message': 'safe_area capi功能实现\n\nSigned-off-by: 陈宝迪 <1020819393@qq.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context/commits/84c8f011751e33a5a4432b72b00fd3c5f31125a8'},
#     {'sha': 'eb35a3acaaff7db0c09cbfd77c6c64656cc855d7',
#      'author': {'email': '1020819393@qq.com', 'name': '陈宝迪'},
#      'message': 'safeArea 功能优化\n\nSigned-off-by: 陈宝迪 <1020819393@qq.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context/commits/eb35a3acaaff7db0c09cbfd77c6c64656cc855d7'},
#     {'sha': '1a7a2dc12df15e0f358fe657d065137899e9ca48',
#      'author': {'email': '1020819393@qq.com', 'name': '陈宝迪'},
#      'message': '适配rnoh新框架\n\nSigned-off-by: 陈宝迪 <1020819393@qq.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context/commits/1a7a2dc12df15e0f358fe657d065137899e9ca48'},
#     {'sha': 'c51c7ba9e624558ebd173b58593f888ec8959d66',
#      'author': {'email': 'chenbaodi2@h-partners.com', 'name': '陈宝迪'},
#      'message': 'node适配rnoh\n\nSigned-off-by: 陈宝迪 <chenbaodi2@h-partners.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context/commits/c51c7ba9e624558ebd173b58593f888ec8959d66'},
#     {'sha': '8102646900d12ee40543db1fecf63fee6c3c1bd8',
#      'author': {'email': 'chenbaodi2@h-partners.com', 'name': '陈宝迪'},
#      'message': 'safe-area-context适配rnoh框架\n\nSigned-off-by: 陈宝迪 <chenbaodi2@h-partners.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context/commits/8102646900d12ee40543db1fecf63fee6c3c1bd8'},
#     {'sha': 'c2198b4fd2d86957690c727164b1bdb8cdbb8da6',
#      'author': {'email': 'chenbaodi2@h-partners.com', 'name': '陈宝迪'},
#      'message': 'safe-area-context修复rawprops无传值异常问题\n\nSigned-off-by: 陈宝迪 <chenbaodi2@h-partners.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context/commits/c2198b4fd2d86957690c727164b1bdb8cdbb8da6'},
#     {'sha': '70f9c61c30c37aa9006195d8b8c9ae77a797b627',
#      'author': {'email': 'chenbaodi2@h-partners.com', 'name': '陈宝迪'},
#      'message': 'safe-area-context优化代码结构\n\nSigned-off-by: 陈宝迪 <chenbaodi2@h-partners.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context/commits/70f9c61c30c37aa9006195d8b8c9ae77a797b627'},
#     {'sha': '0b09f825b4a7b0ce95309e402b921268f68675d2',
#      'author': {'email': 'chenbaodi2@h-partners.com', 'name': '陈宝迪'},
#      'message': 'safe-area-context代码优化\n\nSigned-off-by: 陈宝迪 <chenbaodi2@h-partners.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context/commits/0b09f825b4a7b0ce95309e402b921268f68675d2'},
#     {'sha': '4af3265ce10eb17c4bdf33347a21ea86ef24f2e3',
#      'author': {'email': 'dingchenjie1@h-partners.com',
#       'name': 'ding_chengjie'},
#      'message': 'safe-area发布npm:4.7.4-0.1.1',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context/commits/4af3265ce10eb17c4bdf33347a21ea86ef24f2e3'},
#     {'sha': '884c507e0444bfd700822451c75e7439e02c3d95',
#      'author': {'email': 'wupingyuan2@h-partners.com', 'name': 'wupingyuan'},
#      'message': '修改rnoh->react_native_openharmony',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context/commits/884c507e0444bfd700822451c75e7439e02c3d95'},
#     {'sha': 'cd2e3e549d0b0c71db2724d59752ca953c9206c5',
#      'author': {'email': '61399097+Louis-C7@users.noreply.github.com',
#       'name': 'Louis Chan'},
#      'message': 'Merge pull request #8 from react-native-oh-library/capi\n\nMerge capi into sig',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/react-native-oh-library/react-native-safe-area-context/commits/cd2e3e549d0b0c71db2724d59752ca953c9206c5'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z',
#   'org': {'id': 146327244,
#    'login': 'react-native-oh-library',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/react-native-oh-library',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/146327244?'}},
#  {'id': '37510461690',
#   'type': 'PushEvent',
#   'actor': {'id': 155121578,
#    'login': 'Eehnodu',
#    'display_login': 'Eehnodu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Eehnodu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/155121578?'},
#   'repo': {'id': 787504782,
#    'name': 'Eehnodu/Eehnodu',
#    'url': 'https://api.github.com/repos/Eehnodu/Eehnodu'},
#   'payload': {'repository_id': 787504782,
#    'push_id': 18022982366,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9d3a7573029984d6ae8165e4418e019a1383771c',
#    'before': '85f8eced8b80b304c1fa256cbca65500678fab28',
#    'commits': [{'sha': '9d3a7573029984d6ae8165e4418e019a1383771c',
#      'author': {'email': '155121578+Eehnodu@users.noreply.github.com',
#       'name': '우동희'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Eehnodu/Eehnodu/commits/9d3a7573029984d6ae8165e4418e019a1383771c'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461693',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 376210086,
#    'name': 'DionneNoellaBarretto/dionnenoellabarretto',
#    'url': 'https://api.github.com/repos/DionneNoellaBarretto/dionnenoellabarretto'},
#   'payload': {'repository_id': 376210086,
#    'push_id': 18022982353,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cca51cd0c2a26fb8badc777e400ed445a14d5b85',
#    'before': '38098c5d78654ce3a32797054fcdd04f0ac792b0',
#    'commits': [{'sha': 'cca51cd0c2a26fb8badc777e400ed445a14d5b85',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update with quote-readme',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DionneNoellaBarretto/dionnenoellabarretto/commits/cca51cd0c2a26fb8badc777e400ed445a14d5b85'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461596',
#   'type': 'PushEvent',
#   'actor': {'id': 165675508,
#    'login': 'LeDuonng',
#    'display_login': 'LeDuonng',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LeDuonng',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/165675508?'},
#   'repo': {'id': 783815443,
#    'name': 'LeDuonng/Keylogger-Stealer',
#    'url': 'https://api.github.com/repos/LeDuonng/Keylogger-Stealer'},
#   'payload': {'repository_id': 783815443,
#    'push_id': 18022982329,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '947f09a8aaa7b8f80760793ca9a0c70e1630763b',
#    'before': 'ed9a8a5a751364af429460246c9b7daca97e8a1f',
#    'commits': [{'sha': '43377a8b3ce89fea543176a53baae77c05662122',
#      'author': {'email': '89838052+LeeDuonng@users.noreply.github.com',
#       'name': 'DuongLee'},
#      'message': 'update16042024',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/LeDuonng/Keylogger-Stealer/commits/43377a8b3ce89fea543176a53baae77c05662122'},
#     {'sha': '947f09a8aaa7b8f80760793ca9a0c70e1630763b',
#      'author': {'email': '89838052+LeeDuonng@users.noreply.github.com',
#       'name': 'DuongLee'},
#      'message': 'update16042024',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/LeDuonng/Keylogger-Stealer/commits/947f09a8aaa7b8f80760793ca9a0c70e1630763b'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461623',
#   'type': 'CreateEvent',
#   'actor': {'id': 149362391,
#    'login': 'Dmytro-Hrebenyuk',
#    'display_login': 'Dmytro-Hrebenyuk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dmytro-Hrebenyuk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/149362391?'},
#   'repo': {'id': 787507280,
#    'name': 'Dmytro-Hrebenyuk/LeetCode-Stacks-and-Queues',
#    'url': 'https://api.github.com/repos/Dmytro-Hrebenyuk/LeetCode-Stacks-and-Queues'},
#   'payload': {'ref': 'temp/upload-manifest/209657861-1713286602',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461678',
#   'type': 'PublicEvent',
#   'actor': {'id': 126192475,
#    'login': 'SebastianO1717',
#    'display_login': 'SebastianO1717',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SebastianO1717',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/126192475?'},
#   'repo': {'id': 717242863,
#    'name': 'SebastianO1717/CLRProjects',
#    'url': 'https://api.github.com/repos/SebastianO1717/CLRProjects'},
#   'payload': {},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461659',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 20151382,
#    'login': 'leonidas1712',
#    'display_login': 'leonidas1712',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leonidas1712',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20151382?'},
#   'repo': {'id': 759379041,
#    'name': 'crabscript/rustscript',
#    'url': 'https://api.github.com/repos/crabscript/rustscript'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/crabscript/rustscript/issues/51',
#     'repository_url': 'https://api.github.com/repos/crabscript/rustscript',
#     'labels_url': 'https://api.github.com/repos/crabscript/rustscript/issues/51/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/crabscript/rustscript/issues/51/comments',
#     'events_url': 'https://api.github.com/repos/crabscript/rustscript/issues/51/events',
#     'html_url': 'https://github.com/crabscript/rustscript/pull/51',
#     'id': 2246494649,
#     'node_id': 'PR_kwDOLUM0Yc5s0-yn',
#     'number': 51,
#     'title': 'Add functions',
#     'user': {'login': 'leonidas1712',
#      'id': 20151382,
#      'node_id': 'MDQ6VXNlcjIwMTUxMzgy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/20151382?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/leonidas1712',
#      'html_url': 'https://github.com/leonidas1712',
#      'followers_url': 'https://api.github.com/users/leonidas1712/followers',
#      'following_url': 'https://api.github.com/users/leonidas1712/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/leonidas1712/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/leonidas1712/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/leonidas1712/subscriptions',
#      'organizations_url': 'https://api.github.com/users/leonidas1712/orgs',
#      'repos_url': 'https://api.github.com/users/leonidas1712/repos',
#      'events_url': 'https://api.github.com/users/leonidas1712/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/leonidas1712/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2024-04-16T16:48:29Z',
#     'updated_at': '2024-04-16T16:56:55Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': True,
#     'pull_request': {'url': 'https://api.github.com/repos/crabscript/rustscript/pulls/51',
#      'html_url': 'https://github.com/crabscript/rustscript/pull/51',
#      'diff_url': 'https://github.com/crabscript/rustscript/pull/51.diff',
#      'patch_url': 'https://github.com/crabscript/rustscript/pull/51.patch',
#      'merged_at': None},
#     'body': '- [ ] Function calls\r\n  - [x] Parsing\r\n  - [x] Compilation\r\n  - [ ] Type check\r\n \r\n\r\n- [ ] Function declarations    \r\n  - [ ] Parsing\r\n  - [ ]  Compilation\r\n  - [ ] Type check',
#     'reactions': {'url': 'https://api.github.com/repos/crabscript/rustscript/issues/51/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/crabscript/rustscript/issues/51/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/crabscript/rustscript/issues/comments/2059537691',
#     'html_url': 'https://github.com/crabscript/rustscript/pull/51#issuecomment-2059537691',
#     'issue_url': 'https://api.github.com/repos/crabscript/rustscript/issues/51',
#     'id': 2059537691,
#     'node_id': 'IC_kwDOLUM0Yc56wg0b',
#     'user': {'login': 'leonidas1712',
#      'id': 20151382,
#      'node_id': 'MDQ6VXNlcjIwMTUxMzgy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/20151382?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/leonidas1712',
#      'html_url': 'https://github.com/leonidas1712',
#      'followers_url': 'https://api.github.com/users/leonidas1712/followers',
#      'following_url': 'https://api.github.com/users/leonidas1712/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/leonidas1712/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/leonidas1712/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/leonidas1712/subscriptions',
#      'organizations_url': 'https://api.github.com/users/leonidas1712/orgs',
#      'repos_url': 'https://api.github.com/users/leonidas1712/repos',
#      'events_url': 'https://api.github.com/users/leonidas1712/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/leonidas1712/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2024-04-16T16:56:53Z',
#     'updated_at': '2024-04-16T16:56:53Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '<img width="1306" alt="Screenshot 2024-04-17 at 12 44 51\u202fAM" src="https://github.com/crabscript/rustscript/assets/20151382/6daf040e-5e57-4c23-8db2-c1b316c849e0">\r\n\r\n<img width="884" alt="Screenshot 2024-04-17 at 12 53 53\u202fAM" src="https://github.com/crabscript/rustscript/assets/20151382/11120057-55dc-45b6-b766-59652d40c865">\r\n\r\nThere might be a bug with the VM call microcode.\r\n\r\nBy default, the HW compiler will compile arguments left to right so e.g for math_pow(2,3) it pushes LD math_pow, LDC 2, LDC 3.\r\n\r\nBut the HW’s CALL takes the arguments and puts them at the end (hence i = arity-1 at the start) then decrements the index, so the args passed are in the original order i.e [2,3] again\r\n\r\nHowever with the rst VM, it seems that since the args are added as they are popped, the order is actually reversed so it ends up calling the function with reversed arguments. \r\n\r\nIf you don’t want to reverse the args after adding, you could use VecDeque to to add the arguments to the front instead\r\n\r\n@ForAeons ',
#     'reactions': {'url': 'https://api.github.com/repos/crabscript/rustscript/issues/comments/2059537691/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z',
#   'org': {'id': 160401535,
#    'login': 'crabscript',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/crabscript',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/160401535?'}},
#  {'id': '37510461576',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 37311499,
#    'login': 'onmete',
#    'display_login': 'onmete',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/onmete',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37311499?'},
#   'repo': {'id': 715942193,
#    'name': 'openshift/lightspeed-service',
#    'url': 'https://api.github.com/repos/openshift/lightspeed-service'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/584',
#     'repository_url': 'https://api.github.com/repos/openshift/lightspeed-service',
#     'labels_url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/584/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/584/comments',
#     'events_url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/584/events',
#     'html_url': 'https://github.com/openshift/lightspeed-service/pull/584',
#     'id': 2181660572,
#     'node_id': 'PR_kwDOKqxpMc5pYS1x',
#     'number': 584,
#     'title': 'OLS-136: data to ingress',
#     'user': {'login': 'onmete',
#      'id': 37311499,
#      'node_id': 'MDQ6VXNlcjM3MzExNDk5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/37311499?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/onmete',
#      'html_url': 'https://github.com/onmete',
#      'followers_url': 'https://api.github.com/users/onmete/followers',
#      'following_url': 'https://api.github.com/users/onmete/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/onmete/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/onmete/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/onmete/subscriptions',
#      'organizations_url': 'https://api.github.com/users/onmete/orgs',
#      'repos_url': 'https://api.github.com/users/onmete/repos',
#      'events_url': 'https://api.github.com/users/onmete/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/onmete/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 6183684984,
#       'node_id': 'LA_kwDOKqxpMc8AAAABcJOLeA',
#       'url': 'https://api.github.com/repos/openshift/lightspeed-service/labels/jira/valid-reference',
#       'name': 'jira/valid-reference',
#       'color': '15dd18',
#       'default': False,
#       'description': 'Indicates that this PR references a valid Jira ticket of any type.'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 13,
#     'created_at': '2024-03-12T13:43:42Z',
#     'updated_at': '2024-04-16T16:56:55Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/openshift/lightspeed-service/pulls/584',
#      'html_url': 'https://github.com/openshift/lightspeed-service/pull/584',
#      'diff_url': 'https://github.com/openshift/lightspeed-service/pull/584.diff',
#      'patch_url': 'https://github.com/openshift/lightspeed-service/pull/584.patch',
#      'merged_at': None},
#     'body': '## Description\r\n\r\nScript that collects data, packages it, and sends it to ingress.\r\n\r\nTODO:\r\n\r\n- [x] - code needed from https://github.com/openshift/lightspeed-service/pull/673\r\n- [x] - CI secret https://github.com/openshift/release/pull/50723\r\n\r\n',
#     'reactions': {'url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/584/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/584/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/comments/2059537679',
#     'html_url': 'https://github.com/openshift/lightspeed-service/pull/584#issuecomment-2059537679',
#     'issue_url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/584',
#     'id': 2059537679,
#     'node_id': 'IC_kwDOKqxpMc56wg0P',
#     'user': {'login': 'onmete',
#      'id': 37311499,
#      'node_id': 'MDQ6VXNlcjM3MzExNDk5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/37311499?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/onmete',
#      'html_url': 'https://github.com/onmete',
#      'followers_url': 'https://api.github.com/users/onmete/followers',
#      'following_url': 'https://api.github.com/users/onmete/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/onmete/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/onmete/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/onmete/subscriptions',
#      'organizations_url': 'https://api.github.com/users/onmete/orgs',
#      'repos_url': 'https://api.github.com/users/onmete/repos',
#      'events_url': 'https://api.github.com/users/onmete/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/onmete/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2024-04-16T16:56:53Z',
#     'updated_at': '2024-04-16T16:56:53Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "I'll squash after the review is done.",
#     'reactions': {'url': 'https://api.github.com/repos/openshift/lightspeed-service/issues/comments/2059537679/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z',
#   'org': {'id': 792337,
#    'login': 'openshift',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openshift',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/792337?'}},
#  {'id': '37510461567',
#   'type': 'PushEvent',
#   'actor': {'id': 9683221,
#    'login': 'kentatbrtt',
#    'display_login': 'kentatbrtt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kentatbrtt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9683221?'},
#   'repo': {'id': 146010,
#    'name': 'antelopeusersgroup/antelope_contrib',
#    'url': 'https://api.github.com/repos/antelopeusersgroup/antelope_contrib'},
#   'payload': {'repository_id': 146010,
#    'push_id': 18022982297,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/brttnext',
#    'head': '6cbf30158562d063f5b3f4b4fe976009890c9f35',
#    'before': '1411364a7c058df49de418b42de8fc17bd93be1c',
#    'commits': [{'sha': '6cbf30158562d063f5b3f4b4fe976009890c9f35',
#      'author': {'email': 'kent@brtt.com', 'name': 'Kent Lindquist'},
#      'message': 'Fix CLEAN target in install_obspy',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/antelopeusersgroup/antelope_contrib/commits/6cbf30158562d063f5b3f4b4fe976009890c9f35'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z',
#   'org': {'id': 61360,
#    'login': 'antelopeusersgroup',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/antelopeusersgroup',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61360?'}},
#  {'id': '37510461542',
#   'type': 'PushEvent',
#   'actor': {'id': 167233616,
#    'login': 'madenapujitha',
#    'display_login': 'madenapujitha',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/madenapujitha',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/167233616?'},
#   'repo': {'id': 787507255,
#    'name': 'madenapujitha/webtechnologies',
#    'url': 'https://api.github.com/repos/madenapujitha/webtechnologies'},
#   'payload': {'repository_id': 787507255,
#    'push_id': 18022982298,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '1de351bd48d220ec1c2f343276674f1a099b9d13',
#    'before': '700ba83cb9dd0827db3a930d0662bc85ff4c8ffe',
#    'commits': [{'sha': '1de351bd48d220ec1c2f343276674f1a099b9d13',
#      'author': {'email': '167233616+madenapujitha@users.noreply.github.com',
#       'name': 'madenapujitha'},
#      'message': 'Update sample.html with deleting heading tags',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/madenapujitha/webtechnologies/commits/1de351bd48d220ec1c2f343276674f1a099b9d13'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461561',
#   'type': 'PushEvent',
#   'actor': {'id': 85644782,
#    'login': 'trunk-io[bot]',
#    'display_login': 'trunk-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/trunk-io[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/85644782?'},
#   'repo': {'id': 777900545,
#    'name': 'trunk-io/mergequeue',
#    'url': 'https://api.github.com/repos/trunk-io/mergequeue'},
#   'payload': {'repository_id': 777900545,
#    'push_id': 18022982286,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/trunk-temp/pr-28994/96b57c45-1a15-4fbb-a7ff-0e8f62d5d9e7',
#    'head': 'cfa23263b6b1d187d53d99fd931fe4fc2ef992a5',
#    'before': '10d29297a73cbbf053c58226da86c1147af3cc87',
#    'commits': [{'sha': '54968060a9c4c419949f2ad1e4797fd4125f1805',
#      'author': {'email': 'bot@trunk.io', 'name': 'trunk bot'},
#      'message': 'Moving words durn, fessways',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/trunk-io/mergequeue/commits/54968060a9c4c419949f2ad1e4797fd4125f1805'},
#     {'sha': 'cfa23263b6b1d187d53d99fd931fe4fc2ef992a5',
#      'author': {'email': '85644782+trunk-io[bot]@users.noreply.github.com',
#       'name': 'trunk-io[bot]'},
#      'message': 'Merging 54968060a9c4c419949f2ad1e4797fd4125f1805 into trunk-temp/pr-28994/96b57c45-1a15-4fbb-a7ff-0e8f62d5d9e7',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/trunk-io/mergequeue/commits/cfa23263b6b1d187d53d99fd931fe4fc2ef992a5'}]},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z',
#   'org': {'id': 74779146,
#    'login': 'trunk-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/trunk-io',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74779146?'}},
#  {'id': '37510461548',
#   'type': 'DeleteEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 439684068,
#    'name': 'andreoliwa/conjuring',
#    'url': 'https://api.github.com/repos/andreoliwa/conjuring'},
#   'payload': {'ref': 'branches/renovate/pylint-3.x-lockfile',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z'},
#  {'id': '37510461518',
#   'type': 'CreateEvent',
#   'actor': {'id': 22119113,
#    'login': 'jhenrique09',
#    'display_login': 'jhenrique09',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jhenrique09',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22119113?'},
#   'repo': {'id': 787509318,
#    'name': 'pe-blobs/vendor_google_sargo',
#    'url': 'https://api.github.com/repos/pe-blobs/vendor_google_sargo'},
#   'payload': {'ref': 'twelve',
#    'ref_type': 'branch',
#    'master_branch': 'eleven',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-04-16T16:56:55Z',
#   'org': {'id': 167211182,
#    'login': 'pe-blobs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/pe-blobs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/167211182?'}}]

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
r.json()
# Out:
# ['2022-11-28']

# %%
r = requests.get('https://api.github.com/users/enricoasc')
r.status_code
r.json()
# r.url

print(f'Nome da conta : '+r.json()['name'])
print(f'Login da conta : '+r.json()['login'])
print(f'Quantidade de repositórios públicos : '+str(r.json()['public_repos']))
print(f'Data de criação da conta : '+r.json()['created_at'])
# Out:
# Nome da conta : Enrico Augusto
# Login da conta : enricoasc
# Quantidade de repositórios públicos : 6
# Data de criação da conta : 2021-05-31T11:15:08Z
